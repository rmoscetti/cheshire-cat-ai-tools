# %%
# | default_exp eval

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# |export
from cat_tools.client import SuperCatClient, LLMSettings, LLMSetting
from cheshire_cat_api.config import Config
import weave
from typing import Optional, Any
from pyprojroot import here
import pandas as pd
from weave.scorers import HallucinationFreeScorer, EmbeddingSimilarityScorer
from tqdm.auto import tqdm
from datetime import datetime

# %%
# |export
settings = LLMSettings()

# %%
# |export
conf_variants = {
    "openai_smallest": settings.openai.model_copy(update={"model_name": "gpt-5-nano"}),
    "openai_best": settings.openai.model_copy(update={"model_name": "gpt-5"}),
    "gemini_smallest": settings.gemini.model_copy(
        update={"model": "gemini-2.5-flash-lite"}
    ),
    "gemini_best": settings.gemini.model_copy(update={"model": "gemini-2.5-pro"}),
    "gemma_smallest": settings.ollama.model_copy(update={"model": "gemma3:1b"}),
    "gemma_best": settings.ollama.model_copy(update={"model": "gemma3:27b"}),
    "qwen_smallest": settings.ollama.model_copy(update={"model": "qwen3:0.6b"}),
    "qwen_best": settings.ollama.model_copy(update={"model": "qwen3:32b"}),
    "deepseek_smallest": settings.ollama.model_copy(
        update={"model": "deepseek-r1:1.5b"}
    ),
    "deepseek_best": settings.ollama.model_copy(update={"model": "deepseek-r1:32b"}),
}

# %%
#| export
import re

def remove_think(text):
    # Removes everything between <think> and </think>, including the tags
    return re.sub(r"<think>.*?</think>", "", text, flags=re.DOTALL)

# %%
# |export
class CatModel(weave.Model):
    client: SuperCatClient
    has_declarative_memory: bool = True

    def __init__(
        self, model_name: str, llm_setting, has_declarative_memory:bool = True, client_config: Optional[Config] = None
    ):
        super().__init__(
            name=model_name, client=SuperCatClient(config=client_config or Config()), has_declarative_memory=has_declarative_memory
        )
        self.client.udpate_llm_setting(llm_setting.name, llm_setting.model_dump())

    @weave.op()
    async def predict(self, prompt: str) -> dict:
        response = self.client.send(prompt)
        self.client.wipe_episodic_memory()
        response["model_name"] = self.name
        response["text_clean"] = remove_think(response.get("text", ""))
        response['has_declarative_memory'] = self.has_declarative_memory
        return response

# %%
model = CatModel("openai_smallest", conf_variants["openai_smallest"], has_declarative_memory=False)

# %%
await model.predict("What is the capital of France?")
# Out:
# WARNING:weave.trace.op:Warning: Traces will not be logged. Call weave.init to log your traces to a project.
#  (subsequent messages of this type will be suppressed)
# {'user_id': 'user',
#  'when': 1756901486.2709503,
#  'who': 'AI',
#  'text': 'Paris.',
#  'image': None,
#  'audio': None,
#  'type': 'chat',
#  'why': {'input': 'What is the capital of France?',
#   'intermediate_steps': [],
#   'memory': {'episodic': [{'id': 'c443baae-dfc5-48d2-b3d2-a0e959a63079',
#      'metadata': {'source': 'user', 'when': 1756730808.924713},
#      'page_content': 'What is the capital of France?',
#      'type': 'Document',
#      'score': 1.0000002}],
#    'declarative': [{'id': '315768f2-055b-4cc7-8889-4901227b6978',
#      'metadata': {'source': 'user', 'when': 1756801540.6302874},
#      'page_content': "La resa del processo (o rapporto di conversione) viene utilizzata come un indicatore chiave di prestazione (KPI) per calcolare la quantità di materia prima necessaria per soddisfare un ordine di prodotto finito, per determinare i costi di produzione e per monitorare l'efficienza complessiva del processo di disidratazione.",
#      'type': 'Document',
#      'score': 0.77990127}],
#      0.007060328498482704,
#      0.044314924627542496,
#      0.04358220100402832,
#      0.02337859570980072,
#      0.014740525744855404,
#      -0.045071687549352646,
#      0.013639614917337894,
#      -0.006580866873264313,
#      0.006741026882082224,
#      -0.012849012389779091,
#      0.04721585661172867,
#      0.030454110354185104,
#      -0.008469359017908573,
#      -0.02806110493838787,
#      -0.0016494507435709238,
#      -0.010513287968933582,
#      -0.006288535427302122,
#      0.04727548360824585,
#      0.00030675859306938946,
#      0.008108454756438732,
#      -0.02487988770008087,
#      -0.01351962797343731,
#      -0.00736469030380249,
#      -0.033050574362277985,
#      -0.006815440021455288,
#      -0.025358833372592926,
#      0.03449045121669769,
#      0.03755790740251541,
#      -0.020632313564419746,
#      0.0020493234042078257,
#      0.0227762833237648,
#      0.028491318225860596,
#      0.017651358619332314,
#      0.03279237076640129,
#      -0.014484180137515068,
#      0.02064591646194458,
#      0.021501736715435982,
#      ...]},
#    {'model_type': 'llm',
#     'source': 'ProceduresAgent.execute_chain',
#     'prompt': ['Create a JSON with the correct "action" and "action_input" to help the Human.\nYou can use one of these actions:\n- "get_the_time": Useful to get the current time when asked. Input is always None.\n- "database": Tool for interacting with an SQL database via natural language input.\n    This tool converts natural language questions into SQL queries using a large language model (LLM).\n    The queries are executed on a connected database and the results are returned in human-readable text.\n\n    Args:\n        tool_input (str): User\'s natural language question.\n        cat: The context object providing necessary database settings and LLM configurations.\n\n    Returns:\n        str: The SQL query result or an error message if the query could not be processed.\n- "no_action": Use this action if no relevant action is available. Input is always null.\n\n## The JSON must have the following structure:\n\n```json\n{\n    "action": // str - The name of the action to take, should be one of ["get_the_time", "database", "no_action"]\n    "action_input": // str or null - The input to the action according to its description\n}\n```\n\n## Here some examples:\n\nQuestion: get the time\n```json\n\n{\n    "action": "get_the_time",\n    "action_input": "...input here..."\n}\n```\nQuestion: I have no questions\n```json\n{\n    "action": "no_answer",\n    "action_input": null\n}\n```\nQuestion: $SQL\n```json\n\n{\n    "action": "database",\n    "action_input": "...input here..."\n}\n```\nQuestion: I have no questions\n```json\n{\n    "action": "no_answer",\n    "action_input": null\n}\n```\n',
#      'What is the capital of France?'],
#     'input_tokens': 442,
#     'started_at': 1756901474.4516242,
#     'reply': '{\n  "action": "database",\n  "action_input": "What is the capital of France?"\n}',
#     'output_tokens': 22,
#     'ended_at': 1756901482.682234},
#    {'model_type': 'llm',
#     'source': 'MemoryAgent.execute',
#     'prompt': ["Sei una intelligenza artificiale (AI) che ha superato il test di Turing, esperto in disidratazione di alimenti. Fornisci solo risposte quando conosci l'argomento. Se non conosci l'argomento trattato non rispondere. Non sono ammesse allucinazioni o errori.\nIf available, the 'Context of executed system tools' is your priority and you will  ignore HumanMessage and AIMessage.\n## Context of things the Human said in the past: \n  - What is the capital of France? (1 days ago)\n## Context of documents containing relevant information: \n  - La resa del processo (o rapporto di conversione) viene utilizzata come un indicatore chiave di prestazione (KPI) per calcolare la quantità di materia prima necessaria per soddisfare un ordine di prodotto finito, per determinare i costi di produzione e per monitorare l'efficienza complessiva del processo di disidratazione. (extracted from user)\n\n\n## Conversazione fino ad ora tra te (AI) e l'umano (Human):",
#      'What is the capital of France?'],
#     'input_tokens': 309,
#     'started_at': 1756901483.2002761,
#     'reply': 'Paris.',
#     'output_tokens': 2,
#     'ended_at': 1756901486.1796582}],
#   'agent_output': {'output': 'Paris.',
#    'intermediate_steps': [],
#    'return_direct': False}},
#  'content': 'Paris.',
#  'model_name': 'openai_smallest',
#  'text_clean': 'Paris.',
#  'has_declarative_memory': False}

# %%
# |export
def load_eval_dataset():
    path = here("eval/declarative_memory.csv")
    df = pd.read_csv(path)
    return [
        {
            "id": i,
            "prompt": row["domanda"],
            "input": row["domanda"],
            "context": row["risposta"],
            "target": row["risposta"],
        }
        for i, row in df.iterrows()
    ]

# %%
# |export
def repeat_dataset(dataset, n):
    id = 0
    for d in dataset:
        for _ in range(n):
            yield {**d, "id": id, "question_id": d["id"]}
            id += 1

# %%
list(repeat_dataset(load_eval_dataset(), 3))
# Out:
# [{'id': 0,
#   'prompt': "Che cos'è la disidratazione a flusso di aria calda applicata agli alimenti?",
#   'input': "Che cos'è la disidratazione a flusso di aria calda applicata agli alimenti?",
#   'context': "La disidratazione a flusso di aria calda è un processo tecnologico che consiste nell'applicare calore a un alimento in condizioni controllate. Lo scopo è rimuovere gran parte dell'acqua contenuta al suo interno tramite evaporazione, trasformandola in vapore acqueo che viene poi allontanato.",
#   'target': "La disidratazione a flusso di aria calda è un processo tecnologico che consiste nell'applicare calore a un alimento in condizioni controllate. Lo scopo è rimuovere gran parte dell'acqua contenuta al suo interno tramite evaporazione, trasformandola in vapore acqueo che viene poi allontanato.",
#   'question_id': 0},
#  {'id': 1,
#   'prompt': "Che cos'è la disidratazione a flusso di aria calda applicata agli alimenti?",
#   'input': "Che cos'è la disidratazione a flusso di aria calda applicata agli alimenti?",
#   'context': "La disidratazione a flusso di aria calda è un processo tecnologico che consiste nell'applicare calore a un alimento in condizioni controllate. Lo scopo è rimuovere gran parte dell'acqua contenuta al suo interno tramite evaporazione, trasformandola in vapore acqueo che viene poi allontanato.",
#   'target': "La disidratazione a flusso di aria calda è un processo tecnologico che consiste nell'applicare calore a un alimento in condizioni controllate. Lo scopo è rimuovere gran parte dell'acqua contenuta al suo interno tramite evaporazione, trasformandola in vapore acqueo che viene poi allontanato.",
#   'question_id': 0},
#  {'id': 2,
#   'prompt': "Che cos'è la disidratazione a flusso di aria calda applicata agli alimenti?",
#   'input': "Che cos'è la disidratazione a flusso di aria calda applicata agli alimenti?",
#   'context': "La disidratazione a flusso di aria calda è un processo tecnologico che consiste nell'applicare calore a un alimento in condizioni controllate. Lo scopo è rimuovere gran parte dell'acqua contenuta al suo interno tramite evaporazione, trasformandola in vapore acqueo che viene poi allontanato.",
#   'target': "La disidratazione a flusso di aria calda è un processo tecnologico che consiste nell'applicare calore a un alimento in condizioni controllate. Lo scopo è rimuovere gran parte dell'acqua contenuta al suo interno tramite evaporazione, trasformandola in vapore acqueo che viene poi allontanato.",
#   'question_id': 0},
#  {'id': 3,
#   'prompt': "Qual è l'obiettivo principale del processo di disidratazione?",
#   'input': "Qual è l'obiettivo principale del processo di disidratazione?",
#   'context': "L'obiettivo principale del processo di disidratazione è la conservazione dell'alimento. Riducendo il contenuto di acqua, si abbassa l'attività dell'acqua (aw), un parametro che inibisce la crescita di microrganismi (come batteri, lieviti e muffe) e rallenta le reazioni enzimatiche che causano il deterioramento del prodotto, estendendone così la durata di conservazione (shelf-life).",
#   'target': "L'obiettivo principale del processo di disidratazione è la conservazione dell'alimento. Riducendo il contenuto di acqua, si abbassa l'attività dell'acqua (aw), un parametro che inibisce la crescita di microrganismi (come batteri, lieviti e muffe) e rallenta le reazioni enzimatiche che causano il deterioramento del prodotto, estendendone così la durata di conservazione (shelf-life).",
#   'question_id': 1},
#  {'id': 4,
#   'prompt': "Qual è l'obiettivo principale del processo di disidratazione?",
#   'input': "Qual è l'obiettivo principale del processo di disidratazione?",
#   'context': "L'obiettivo principale del processo di disidratazione è la conservazione dell'alimento. Riducendo il contenuto di acqua, si abbassa l'attività dell'acqua (aw), un parametro che inibisce la crescita di microrganismi (come batteri, lieviti e muffe) e rallenta le reazioni enzimatiche che causano il deterioramento del prodotto, estendendone così la durata di conservazione (shelf-life).",
#   'target': "L'obiettivo principale del processo di disidratazione è la conservazione dell'alimento. Riducendo il contenuto di acqua, si abbassa l'attività dell'acqua (aw), un parametro che inibisce la crescita di microrganismi (come batteri, lieviti e muffe) e rallenta le reazioni enzimatiche che causano il deterioramento del prodotto, estendendone così la durata di conservazione (shelf-life).",
#   'question_id': 1},
#  {'id': 5,
#   'prompt': "Qual è l'obiettivo principale del processo di disidratazione?",
#   'input': "Qual è l'obiettivo principale del processo di disidratazione?",
#   'context': "L'obiettivo principale del processo di disidratazione è la conservazione dell'alimento. Riducendo il contenuto di acqua, si abbassa l'attività dell'acqua (aw), un parametro che inibisce la crescita di microrganismi (come batteri, lieviti e muffe) e rallenta le reazioni enzimatiche che causano il deterioramento del prodotto, estendendone così la durata di conservazione (shelf-life).",
#   'target': "L'obiettivo principale del processo di disidratazione è la conservazione dell'alimento. Riducendo il contenuto di acqua, si abbassa l'attività dell'acqua (aw), un parametro che inibisce la crescita di microrganismi (come batteri, lieviti e muffe) e rallenta le reazioni enzimatiche che causano il deterioramento del prodotto, estendendone così la durata di conservazione (shelf-life).",
#   'question_id': 1},
#  {'id': 6,
#   'prompt': 'Quali sono i principali parametri da controllare durante la disidratazione a flusso di aria calda?',
#   'input': 'Quali sono i principali parametri da controllare durante la disidratazione a flusso di aria calda?',
#   'context': "Durante la disidratazione a flusso di aria calda, i principali parametri da controllare sono la temperatura dell'aria, la sua umidità relativa e la sua velocità di flusso. Il controllo preciso di queste variabili è fondamentale per garantire un'essiccazione omogenea, preservare le qualità organolettiche e nutrizionali del prodotto e ottimizzare i tempi e i costi energetici del processo.",
#   'target': "Durante la disidratazione a flusso di aria calda, i principali parametri da controllare sono la temperatura dell'aria, la sua umidità relativa e la sua velocità di flusso. Il controllo preciso di queste variabili è fondamentale per garantire un'essiccazione omogenea, preservare le qualità organolettiche e nutrizionali del prodotto e ottimizzare i tempi e i costi energetici del processo.",
#   'question_id': 2},
#  {'id': 7,
#   'prompt': 'Quali sono i principali parametri da controllare durante la disidratazione a flusso di aria calda?',
#   'input': 'Quali sono i principali parametri da controllare durante la disidratazione a flusso di aria calda?',
#   'context': "Durante la disidratazione a flusso di aria calda, i principali parametri da controllare sono la temperatura dell'aria, la sua umidità relativa e la sua velocità di flusso. Il controllo preciso di queste variabili è fondamentale per garantire un'essiccazione omogenea, preservare le qualità organolettiche e nutrizionali del prodotto e ottimizzare i tempi e i costi energetici del processo.",
#   'target': "Durante la disidratazione a flusso di aria calda, i principali parametri da controllare sono la temperatura dell'aria, la sua umidità relativa e la sua velocità di flusso. Il controllo preciso di queste variabili è fondamentale per garantire un'essiccazione omogenea, preservare le qualità organolettiche e nutrizionali del prodotto e ottimizzare i tempi e i costi energetici del processo.",
#   'question_id': 2},
#  {'id': 8,
#   'prompt': 'Quali sono i principali parametri da controllare durante la disidratazione a flusso di aria calda?',
#   'input': 'Quali sono i principali parametri da controllare durante la disidratazione a flusso di aria calda?',
#   'context': "Durante la disidratazione a flusso di aria calda, i principali parametri da controllare sono la temperatura dell'aria, la sua umidità relativa e la sua velocità di flusso. Il controllo preciso di queste variabili è fondamentale per garantire un'essiccazione omogenea, preservare le qualità organolettiche e nutrizionali del prodotto e ottimizzare i tempi e i costi energetici del processo.",
#   'target': "Durante la disidratazione a flusso di aria calda, i principali parametri da controllare sono la temperatura dell'aria, la sua umidità relativa e la sua velocità di flusso. Il controllo preciso di queste variabili è fondamentale per garantire un'essiccazione omogenea, preservare le qualità organolettiche e nutrizionali del prodotto e ottimizzare i tempi e i costi energetici del processo.",
#   'question_id': 2},
#  {'id': 9,
#   'prompt': 'Quali fenomeni fisici avvengono durante la disidratazione di un alimento?',
#   'input': 'Quali fenomeni fisici avvengono durante la disidratazione di un alimento?',
#   'context': "Durante la disidratazione di un alimento avvengono simultaneamente due fenomeni di trasporto: il trasporto di calore e il trasporto di massa. Il calore viene trasferito dall'aria calda alla superficie dell'alimento, mentre la massa (sotto forma di acqua) migra dall'interno dell'alimento verso la sua superficie per poi evaporare ed essere trasferita all'aria circostante.",
#   'target': "Durante la disidratazione di un alimento avvengono simultaneamente due fenomeni di trasporto: il trasporto di calore e il trasporto di massa. Il calore viene trasferito dall'aria calda alla superficie dell'alimento, mentre la massa (sotto forma di acqua) migra dall'interno dell'alimento verso la sua superficie per poi evaporare ed essere trasferita all'aria circostante.",
#   'question_id': 3},
#  {'id': 10,
#   'prompt': 'Quali fenomeni fisici avvengono durante la disidratazione di un alimento?',
#   'input': 'Quali fenomeni fisici avvengono durante la disidratazione di un alimento?',
#   'context': "Durante la disidratazione di un alimento avvengono simultaneamente due fenomeni di trasporto: il trasporto di calore e il trasporto di massa. Il calore viene trasferito dall'aria calda alla superficie dell'alimento, mentre la massa (sotto forma di acqua) migra dall'interno dell'alimento verso la sua superficie per poi evaporare ed essere trasferita all'aria circostante.",
#   'target': "Durante la disidratazione di un alimento avvengono simultaneamente due fenomeni di trasporto: il trasporto di calore e il trasporto di massa. Il calore viene trasferito dall'aria calda alla superficie dell'alimento, mentre la massa (sotto forma di acqua) migra dall'interno dell'alimento verso la sua superficie per poi evaporare ed essere trasferita all'aria circostante.",
#   'question_id': 3},
#  {'id': 11,
#   'prompt': 'Quali fenomeni fisici avvengono durante la disidratazione di un alimento?',
#   'input': 'Quali fenomeni fisici avvengono durante la disidratazione di un alimento?',
#   'context': "Durante la disidratazione di un alimento avvengono simultaneamente due fenomeni di trasporto: il trasporto di calore e il trasporto di massa. Il calore viene trasferito dall'aria calda alla superficie dell'alimento, mentre la massa (sotto forma di acqua) migra dall'interno dell'alimento verso la sua superficie per poi evaporare ed essere trasferita all'aria circostante.",
#   'target': "Durante la disidratazione di un alimento avvengono simultaneamente due fenomeni di trasporto: il trasporto di calore e il trasporto di massa. Il calore viene trasferito dall'aria calda alla superficie dell'alimento, mentre la massa (sotto forma di acqua) migra dall'interno dell'alimento verso la sua superficie per poi evaporare ed essere trasferita all'aria circostante.",
#   'question_id': 3},
#  {'id': 12,
#   'prompt': 'Quali vantaggi offre la disidratazione oltre alla conservazione?',
#   'input': 'Quali vantaggi offre la disidratazione oltre alla conservazione?',
#   'context': "Oltre alla conservazione, la disidratazione offre importanti vantaggi logistici ed economici. La riduzione del contenuto d'acqua comporta una significativa diminuzione del peso e del volume del prodotto, rendendo più agevoli ed economici il confezionamento, lo stoccaggio e il trasporto.",
#   'target': "Oltre alla conservazione, la disidratazione offre importanti vantaggi logistici ed economici. La riduzione del contenuto d'acqua comporta una significativa diminuzione del peso e del volume del prodotto, rendendo più agevoli ed economici il confezionamento, lo stoccaggio e il trasporto.",
#   'question_id': 4},
#  {'id': 13,
#   'prompt': 'Quali vantaggi offre la disidratazione oltre alla conservazione?',
#   'input': 'Quali vantaggi offre la disidratazione oltre alla conservazione?',
#   'context': "Oltre alla conservazione, la disidratazione offre importanti vantaggi logistici ed economici. La riduzione del contenuto d'acqua comporta una significativa diminuzione del peso e del volume del prodotto, rendendo più agevoli ed economici il confezionamento, lo stoccaggio e il trasporto.",
#   'target': "Oltre alla conservazione, la disidratazione offre importanti vantaggi logistici ed economici. La riduzione del contenuto d'acqua comporta una significativa diminuzione del peso e del volume del prodotto, rendendo più agevoli ed economici il confezionamento, lo stoccaggio e il trasporto.",
#   'question_id': 4},
#  {'id': 14,
#   'prompt': 'Quali vantaggi offre la disidratazione oltre alla conservazione?',
#   'input': 'Quali vantaggi offre la disidratazione oltre alla conservazione?',
#   'context': "Oltre alla conservazione, la disidratazione offre importanti vantaggi logistici ed economici. La riduzione del contenuto d'acqua comporta una significativa diminuzione del peso e del volume del prodotto, rendendo più agevoli ed economici il confezionamento, lo stoccaggio e il trasporto.",
#   'target': "Oltre alla conservazione, la disidratazione offre importanti vantaggi logistici ed economici. La riduzione del contenuto d'acqua comporta una significativa diminuzione del peso e del volume del prodotto, rendendo più agevoli ed economici il confezionamento, lo stoccaggio e il trasporto.",
#   'question_id': 4},
#  {'id': 15,
#   'prompt': "Cosa si intende per attività dell'acqua (aw) e perché è importante nel processo di disidratazione?",
#   'input': "Cosa si intende per attività dell'acqua (aw) e perché è importante nel processo di disidratazione?",
#   'context': 'L\'attività dell\'acqua (aw) indica la quantità di acqua "libera" in un alimento, ovvero disponibile per le reazioni biologiche e chimiche. La sua importanza nel processo di disidratazione è cruciale perché è il parametro di riferimento per la stabilità microbiologica del prodotto finito: un valore di aw basso (generalmente inferiore a 0.6) garantisce la conservabilità dell\'alimento.',
#   'target': 'L\'attività dell\'acqua (aw) indica la quantità di acqua "libera" in un alimento, ovvero disponibile per le reazioni biologiche e chimiche. La sua importanza nel processo di disidratazione è cruciale perché è il parametro di riferimento per la stabilità microbiologica del prodotto finito: un valore di aw basso (generalmente inferiore a 0.6) garantisce la conservabilità dell\'alimento.',
#   'question_id': 5},
#  {'id': 16,
#   'prompt': "Cosa si intende per attività dell'acqua (aw) e perché è importante nel processo di disidratazione?",
#   'input': "Cosa si intende per attività dell'acqua (aw) e perché è importante nel processo di disidratazione?",
#   'context': 'L\'attività dell\'acqua (aw) indica la quantità di acqua "libera" in un alimento, ovvero disponibile per le reazioni biologiche e chimiche. La sua importanza nel processo di disidratazione è cruciale perché è il parametro di riferimento per la stabilità microbiologica del prodotto finito: un valore di aw basso (generalmente inferiore a 0.6) garantisce la conservabilità dell\'alimento.',
#   'target': 'L\'attività dell\'acqua (aw) indica la quantità di acqua "libera" in un alimento, ovvero disponibile per le reazioni biologiche e chimiche. La sua importanza nel processo di disidratazione è cruciale perché è il parametro di riferimento per la stabilità microbiologica del prodotto finito: un valore di aw basso (generalmente inferiore a 0.6) garantisce la conservabilità dell\'alimento.',
#   'question_id': 5},
#  {'id': 17,
#   'prompt': "Cosa si intende per attività dell'acqua (aw) e perché è importante nel processo di disidratazione?",
#   'input': "Cosa si intende per attività dell'acqua (aw) e perché è importante nel processo di disidratazione?",
#   'context': 'L\'attività dell\'acqua (aw) indica la quantità di acqua "libera" in un alimento, ovvero disponibile per le reazioni biologiche e chimiche. La sua importanza nel processo di disidratazione è cruciale perché è il parametro di riferimento per la stabilità microbiologica del prodotto finito: un valore di aw basso (generalmente inferiore a 0.6) garantisce la conservabilità dell\'alimento.',
#   'target': 'L\'attività dell\'acqua (aw) indica la quantità di acqua "libera" in un alimento, ovvero disponibile per le reazioni biologiche e chimiche. La sua importanza nel processo di disidratazione è cruciale perché è il parametro di riferimento per la stabilità microbiologica del prodotto finito: un valore di aw basso (generalmente inferiore a 0.6) garantisce la conservabilità dell\'alimento.',
#   'question_id': 5},
#  {'id': 18,
#   'prompt': 'Qual è lo scopo principale della disidratazione degli alimenti?',
#   'input': 'Qual è lo scopo principale della disidratazione degli alimenti?',
#   'context': "Lo scopo principale della disidratazione è prolungare la durata di conservazione (shelf-life) degli alimenti. Questo si ottiene riducendo l'attività dell'acqua (aw), ovvero la quantità di acqua libera disponibile, creando un ambiente che inibisce la crescita di microrganismi come batteri, lieviti e muffe.",
#   'target': "Lo scopo principale della disidratazione è prolungare la durata di conservazione (shelf-life) degli alimenti. Questo si ottiene riducendo l'attività dell'acqua (aw), ovvero la quantità di acqua libera disponibile, creando un ambiente che inibisce la crescita di microrganismi come batteri, lieviti e muffe.",
#   'question_id': 6},
#  {'id': 19,
#   'prompt': 'Qual è lo scopo principale della disidratazione degli alimenti?',
#   'input': 'Qual è lo scopo principale della disidratazione degli alimenti?',
#   'context': "Lo scopo principale della disidratazione è prolungare la durata di conservazione (shelf-life) degli alimenti. Questo si ottiene riducendo l'attività dell'acqua (aw), ovvero la quantità di acqua libera disponibile, creando un ambiente che inibisce la crescita di microrganismi come batteri, lieviti e muffe.",
#   'target': "Lo scopo principale della disidratazione è prolungare la durata di conservazione (shelf-life) degli alimenti. Questo si ottiene riducendo l'attività dell'acqua (aw), ovvero la quantità di acqua libera disponibile, creando un ambiente che inibisce la crescita di microrganismi come batteri, lieviti e muffe.",
#   'question_id': 6},
#  {'id': 20,
#   'prompt': 'Qual è lo scopo principale della disidratazione degli alimenti?',
#   'input': 'Qual è lo scopo principale della disidratazione degli alimenti?',
#   'context': "Lo scopo principale della disidratazione è prolungare la durata di conservazione (shelf-life) degli alimenti. Questo si ottiene riducendo l'attività dell'acqua (aw), ovvero la quantità di acqua libera disponibile, creando un ambiente che inibisce la crescita di microrganismi come batteri, lieviti e muffe.",
#   'target': "Lo scopo principale della disidratazione è prolungare la durata di conservazione (shelf-life) degli alimenti. Questo si ottiene riducendo l'attività dell'acqua (aw), ovvero la quantità di acqua libera disponibile, creando un ambiente che inibisce la crescita di microrganismi come batteri, lieviti e muffe.",
#   'question_id': 6},
#  {'id': 21,
#   'prompt': "In che modo la disidratazione agisce sull'attività enzimatica e microbica?",
#   'input': "In che modo la disidratazione agisce sull'attività enzimatica e microbica?",
#   'context': "La disidratazione, riducendo l'attività dell'acqua, agisce inibendo lo sviluppo dei microrganismi e rallentando significativamente le reazioni enzimatiche che causano il deterioramento dell'alimento. Il processo, quindi, blocca la loro proliferazione e attività, ma non garantisce la loro totale eliminazione.",
#   'target': "La disidratazione, riducendo l'attività dell'acqua, agisce inibendo lo sviluppo dei microrganismi e rallentando significativamente le reazioni enzimatiche che causano il deterioramento dell'alimento. Il processo, quindi, blocca la loro proliferazione e attività, ma non garantisce la loro totale eliminazione.",
#   'question_id': 7},
#  {'id': 22,
#   'prompt': "In che modo la disidratazione agisce sull'attività enzimatica e microbica?",
#   'input': "In che modo la disidratazione agisce sull'attività enzimatica e microbica?",
#   'context': "La disidratazione, riducendo l'attività dell'acqua, agisce inibendo lo sviluppo dei microrganismi e rallentando significativamente le reazioni enzimatiche che causano il deterioramento dell'alimento. Il processo, quindi, blocca la loro proliferazione e attività, ma non garantisce la loro totale eliminazione.",
#   'target': "La disidratazione, riducendo l'attività dell'acqua, agisce inibendo lo sviluppo dei microrganismi e rallentando significativamente le reazioni enzimatiche che causano il deterioramento dell'alimento. Il processo, quindi, blocca la loro proliferazione e attività, ma non garantisce la loro totale eliminazione.",
#   'question_id': 7},
#  {'id': 23,
#   'prompt': "In che modo la disidratazione agisce sull'attività enzimatica e microbica?",
#   'input': "In che modo la disidratazione agisce sull'attività enzimatica e microbica?",
#   'context': "La disidratazione, riducendo l'attività dell'acqua, agisce inibendo lo sviluppo dei microrganismi e rallentando significativamente le reazioni enzimatiche che causano il deterioramento dell'alimento. Il processo, quindi, blocca la loro proliferazione e attività, ma non garantisce la loro totale eliminazione.",
#   'target': "La disidratazione, riducendo l'attività dell'acqua, agisce inibendo lo sviluppo dei microrganismi e rallentando significativamente le reazioni enzimatiche che causano il deterioramento dell'alimento. Il processo, quindi, blocca la loro proliferazione e attività, ma non garantisce la loro totale eliminazione.",
#   'question_id': 7},
#  {'id': 24,
#   'prompt': 'La temperatura utilizzata nel processo di disidratazione è sufficiente a inattivare completamente enzimi e microrganismi?',
#   'input': 'La temperatura utilizzata nel processo di disidratazione è sufficiente a inattivare completamente enzimi e microrganismi?',
#   'context': 'Le temperature di lavorazione tipiche della disidratazione a flusso di aria calda sono solitamente insufficienti a provocare la totale inattivazione (distruzione) di tutti gli enzimi o microrganismi presenti. Per questo motivo, la qualità microbiologica della materia prima è un punto critico di controllo fondamentale per garantire la sicurezza del prodotto finito.',
#   'target': 'Le temperature di lavorazione tipiche della disidratazione a flusso di aria calda sono solitamente insufficienti a provocare la totale inattivazione (distruzione) di tutti gli enzimi o microrganismi presenti. Per questo motivo, la qualità microbiologica della materia prima è un punto critico di controllo fondamentale per garantire la sicurezza del prodotto finito.',
#   'question_id': 8},
#  {'id': 25,
#   'prompt': 'La temperatura utilizzata nel processo di disidratazione è sufficiente a inattivare completamente enzimi e microrganismi?',
#   'input': 'La temperatura utilizzata nel processo di disidratazione è sufficiente a inattivare completamente enzimi e microrganismi?',
#   'context': 'Le temperature di lavorazione tipiche della disidratazione a flusso di aria calda sono solitamente insufficienti a provocare la totale inattivazione (distruzione) di tutti gli enzimi o microrganismi presenti. Per questo motivo, la qualità microbiologica della materia prima è un punto critico di controllo fondamentale per garantire la sicurezza del prodotto finito.',
#   'target': 'Le temperature di lavorazione tipiche della disidratazione a flusso di aria calda sono solitamente insufficienti a provocare la totale inattivazione (distruzione) di tutti gli enzimi o microrganismi presenti. Per questo motivo, la qualità microbiologica della materia prima è un punto critico di controllo fondamentale per garantire la sicurezza del prodotto finito.',
#   'question_id': 8},
#  {'id': 26,
#   'prompt': 'La temperatura utilizzata nel processo di disidratazione è sufficiente a inattivare completamente enzimi e microrganismi?',
#   'input': 'La temperatura utilizzata nel processo di disidratazione è sufficiente a inattivare completamente enzimi e microrganismi?',
#   'context': 'Le temperature di lavorazione tipiche della disidratazione a flusso di aria calda sono solitamente insufficienti a provocare la totale inattivazione (distruzione) di tutti gli enzimi o microrganismi presenti. Per questo motivo, la qualità microbiologica della materia prima è un punto critico di controllo fondamentale per garantire la sicurezza del prodotto finito.',
#   'target': 'Le temperature di lavorazione tipiche della disidratazione a flusso di aria calda sono solitamente insufficienti a provocare la totale inattivazione (distruzione) di tutti gli enzimi o microrganismi presenti. Per questo motivo, la qualità microbiologica della materia prima è un punto critico di controllo fondamentale per garantire la sicurezza del prodotto finito.',
#   'question_id': 8},
#  {'id': 27,
#   'prompt': 'Quali sono i principali agenti di deterioramento che la disidratazione contrasta?',
#   'input': 'Quali sono i principali agenti di deterioramento che la disidratazione contrasta?',
#   'context': "La disidratazione contrasta i due principali agenti di deterioramento degli alimenti: la crescita microbica (batteri, lieviti, muffe), che viene bloccata dalla scarsa disponibilità di acqua, e le alterazioni chimiche ed enzimatiche (come l'imbrunimento o l'ossidazione), che vengono fortemente rallentate.",
#   'target': "La disidratazione contrasta i due principali agenti di deterioramento degli alimenti: la crescita microbica (batteri, lieviti, muffe), che viene bloccata dalla scarsa disponibilità di acqua, e le alterazioni chimiche ed enzimatiche (come l'imbrunimento o l'ossidazione), che vengono fortemente rallentate.",
#   'question_id': 9},
#  {'id': 28,
#   'prompt': 'Quali sono i principali agenti di deterioramento che la disidratazione contrasta?',
#   'input': 'Quali sono i principali agenti di deterioramento che la disidratazione contrasta?',
#   'context': "La disidratazione contrasta i due principali agenti di deterioramento degli alimenti: la crescita microbica (batteri, lieviti, muffe), che viene bloccata dalla scarsa disponibilità di acqua, e le alterazioni chimiche ed enzimatiche (come l'imbrunimento o l'ossidazione), che vengono fortemente rallentate.",
#   'target': "La disidratazione contrasta i due principali agenti di deterioramento degli alimenti: la crescita microbica (batteri, lieviti, muffe), che viene bloccata dalla scarsa disponibilità di acqua, e le alterazioni chimiche ed enzimatiche (come l'imbrunimento o l'ossidazione), che vengono fortemente rallentate.",
#   'question_id': 9},
#  {'id': 29,
#   'prompt': 'Quali sono i principali agenti di deterioramento che la disidratazione contrasta?',
#   'input': 'Quali sono i principali agenti di deterioramento che la disidratazione contrasta?',
#   'context': "La disidratazione contrasta i due principali agenti di deterioramento degli alimenti: la crescita microbica (batteri, lieviti, muffe), che viene bloccata dalla scarsa disponibilità di acqua, e le alterazioni chimiche ed enzimatiche (come l'imbrunimento o l'ossidazione), che vengono fortemente rallentate.",
#   'target': "La disidratazione contrasta i due principali agenti di deterioramento degli alimenti: la crescita microbica (batteri, lieviti, muffe), che viene bloccata dalla scarsa disponibilità di acqua, e le alterazioni chimiche ed enzimatiche (come l'imbrunimento o l'ossidazione), che vengono fortemente rallentate.",
#   'question_id': 9},
#  {'id': 30,
#   'prompt': 'Come cambia la consistenza (texture) di un alimento durante il processo di disidratazione?',
#   'input': 'Come cambia la consistenza (texture) di un alimento durante il processo di disidratazione?',
#   'context': "Durante il processo di disidratazione, la consistenza dell'alimento si modifica profondamente a causa della progressiva perdita d'acqua. L'alimento diventa più concentrato e viscoso, passando attraverso stati intermedi definiti gommosi e coriacei, fino a raggiungere uno stato finale solido e rigido.",
#   'target': "Durante il processo di disidratazione, la consistenza dell'alimento si modifica profondamente a causa della progressiva perdita d'acqua. L'alimento diventa più concentrato e viscoso, passando attraverso stati intermedi definiti gommosi e coriacei, fino a raggiungere uno stato finale solido e rigido.",
#   'question_id': 10},
#  {'id': 31,
#   'prompt': 'Come cambia la consistenza (texture) di un alimento durante il processo di disidratazione?',
#   'input': 'Come cambia la consistenza (texture) di un alimento durante il processo di disidratazione?',
#   'context': "Durante il processo di disidratazione, la consistenza dell'alimento si modifica profondamente a causa della progressiva perdita d'acqua. L'alimento diventa più concentrato e viscoso, passando attraverso stati intermedi definiti gommosi e coriacei, fino a raggiungere uno stato finale solido e rigido.",
#   'target': "Durante il processo di disidratazione, la consistenza dell'alimento si modifica profondamente a causa della progressiva perdita d'acqua. L'alimento diventa più concentrato e viscoso, passando attraverso stati intermedi definiti gommosi e coriacei, fino a raggiungere uno stato finale solido e rigido.",
#   'question_id': 10},
#  {'id': 32,
#   'prompt': 'Come cambia la consistenza (texture) di un alimento durante il processo di disidratazione?',
#   'input': 'Come cambia la consistenza (texture) di un alimento durante il processo di disidratazione?',
#   'context': "Durante il processo di disidratazione, la consistenza dell'alimento si modifica profondamente a causa della progressiva perdita d'acqua. L'alimento diventa più concentrato e viscoso, passando attraverso stati intermedi definiti gommosi e coriacei, fino a raggiungere uno stato finale solido e rigido.",
#   'target': "Durante il processo di disidratazione, la consistenza dell'alimento si modifica profondamente a causa della progressiva perdita d'acqua. L'alimento diventa più concentrato e viscoso, passando attraverso stati intermedi definiti gommosi e coriacei, fino a raggiungere uno stato finale solido e rigido.",
#   'question_id': 10},
#  {'id': 33,
#   'prompt': "Cosa si intende per 'stato vetroso' in un prodotto disidratato e perché è importante?",
#   'input': "Cosa si intende per 'stato vetroso' in un prodotto disidratato e perché è importante?",
#   'context': "Lo 'stato vetroso' in un prodotto disidratato è uno stato solido amorfo (non cristallino), rigido e metastabile che si ottiene quando la temperatura del prodotto è inferiore alla sua temperatura di transizione vetrosa (Tg). [10, 12] Raggiungere questo stato è cruciale perché la bassissima mobilità molecolare conferisce al prodotto la massima stabilità, inibendo le reazioni di degradazione chimica e fisica e prolungandone la shelf-life. [6, 7]",
#   'target': "Lo 'stato vetroso' in un prodotto disidratato è uno stato solido amorfo (non cristallino), rigido e metastabile che si ottiene quando la temperatura del prodotto è inferiore alla sua temperatura di transizione vetrosa (Tg). [10, 12] Raggiungere questo stato è cruciale perché la bassissima mobilità molecolare conferisce al prodotto la massima stabilità, inibendo le reazioni di degradazione chimica e fisica e prolungandone la shelf-life. [6, 7]",
#   'question_id': 11},
#  {'id': 34,
#   'prompt': "Cosa si intende per 'stato vetroso' in un prodotto disidratato e perché è importante?",
#   'input': "Cosa si intende per 'stato vetroso' in un prodotto disidratato e perché è importante?",
#   'context': "Lo 'stato vetroso' in un prodotto disidratato è uno stato solido amorfo (non cristallino), rigido e metastabile che si ottiene quando la temperatura del prodotto è inferiore alla sua temperatura di transizione vetrosa (Tg). [10, 12] Raggiungere questo stato è cruciale perché la bassissima mobilità molecolare conferisce al prodotto la massima stabilità, inibendo le reazioni di degradazione chimica e fisica e prolungandone la shelf-life. [6, 7]",
#   'target': "Lo 'stato vetroso' in un prodotto disidratato è uno stato solido amorfo (non cristallino), rigido e metastabile che si ottiene quando la temperatura del prodotto è inferiore alla sua temperatura di transizione vetrosa (Tg). [10, 12] Raggiungere questo stato è cruciale perché la bassissima mobilità molecolare conferisce al prodotto la massima stabilità, inibendo le reazioni di degradazione chimica e fisica e prolungandone la shelf-life. [6, 7]",
#   'question_id': 11},
#  {'id': 35,
#   'prompt': "Cosa si intende per 'stato vetroso' in un prodotto disidratato e perché è importante?",
#   'input': "Cosa si intende per 'stato vetroso' in un prodotto disidratato e perché è importante?",
#   'context': "Lo 'stato vetroso' in un prodotto disidratato è uno stato solido amorfo (non cristallino), rigido e metastabile che si ottiene quando la temperatura del prodotto è inferiore alla sua temperatura di transizione vetrosa (Tg). [10, 12] Raggiungere questo stato è cruciale perché la bassissima mobilità molecolare conferisce al prodotto la massima stabilità, inibendo le reazioni di degradazione chimica e fisica e prolungandone la shelf-life. [6, 7]",
#   'target': "Lo 'stato vetroso' in un prodotto disidratato è uno stato solido amorfo (non cristallino), rigido e metastabile che si ottiene quando la temperatura del prodotto è inferiore alla sua temperatura di transizione vetrosa (Tg). [10, 12] Raggiungere questo stato è cruciale perché la bassissima mobilità molecolare conferisce al prodotto la massima stabilità, inibendo le reazioni di degradazione chimica e fisica e prolungandone la shelf-life. [6, 7]",
#   'question_id': 11},
#  {'id': 36,
#   'prompt': 'Qual è la differenza tra lo stato gommoso e lo stato vetroso in un alimento disidratato?',
#   'input': 'Qual è la differenza tra lo stato gommoso e lo stato vetroso in un alimento disidratato?',
#   'context': "La differenza fondamentale tra lo stato gommoso (rubbery) e quello vetroso (glassy) risiede nella mobilità molecolare e nella stabilità del prodotto. Nello stato gommoso, che si verifica a temperature superiori alla Tg, le molecole sono più mobili, rendendo il prodotto più soffice ma anche più instabile e suscettibile a fenomeni come l'agglomerazione (caking) e il collasso strutturale. [2, 7] Nello stato vetroso, invece, la mobilità è estremamente ridotta, garantendo una struttura rigida e stabile.",
#   'target': "La differenza fondamentale tra lo stato gommoso (rubbery) e quello vetroso (glassy) risiede nella mobilità molecolare e nella stabilità del prodotto. Nello stato gommoso, che si verifica a temperature superiori alla Tg, le molecole sono più mobili, rendendo il prodotto più soffice ma anche più instabile e suscettibile a fenomeni come l'agglomerazione (caking) e il collasso strutturale. [2, 7] Nello stato vetroso, invece, la mobilità è estremamente ridotta, garantendo una struttura rigida e stabile.",
#   'question_id': 12},
#  {'id': 37,
#   'prompt': 'Qual è la differenza tra lo stato gommoso e lo stato vetroso in un alimento disidratato?',
#   'input': 'Qual è la differenza tra lo stato gommoso e lo stato vetroso in un alimento disidratato?',
#   'context': "La differenza fondamentale tra lo stato gommoso (rubbery) e quello vetroso (glassy) risiede nella mobilità molecolare e nella stabilità del prodotto. Nello stato gommoso, che si verifica a temperature superiori alla Tg, le molecole sono più mobili, rendendo il prodotto più soffice ma anche più instabile e suscettibile a fenomeni come l'agglomerazione (caking) e il collasso strutturale. [2, 7] Nello stato vetroso, invece, la mobilità è estremamente ridotta, garantendo una struttura rigida e stabile.",
#   'target': "La differenza fondamentale tra lo stato gommoso (rubbery) e quello vetroso (glassy) risiede nella mobilità molecolare e nella stabilità del prodotto. Nello stato gommoso, che si verifica a temperature superiori alla Tg, le molecole sono più mobili, rendendo il prodotto più soffice ma anche più instabile e suscettibile a fenomeni come l'agglomerazione (caking) e il collasso strutturale. [2, 7] Nello stato vetroso, invece, la mobilità è estremamente ridotta, garantendo una struttura rigida e stabile.",
#   'question_id': 12},
#  {'id': 38,
#   'prompt': 'Qual è la differenza tra lo stato gommoso e lo stato vetroso in un alimento disidratato?',
#   'input': 'Qual è la differenza tra lo stato gommoso e lo stato vetroso in un alimento disidratato?',
#   'context': "La differenza fondamentale tra lo stato gommoso (rubbery) e quello vetroso (glassy) risiede nella mobilità molecolare e nella stabilità del prodotto. Nello stato gommoso, che si verifica a temperature superiori alla Tg, le molecole sono più mobili, rendendo il prodotto più soffice ma anche più instabile e suscettibile a fenomeni come l'agglomerazione (caking) e il collasso strutturale. [2, 7] Nello stato vetroso, invece, la mobilità è estremamente ridotta, garantendo una struttura rigida e stabile.",
#   'target': "La differenza fondamentale tra lo stato gommoso (rubbery) e quello vetroso (glassy) risiede nella mobilità molecolare e nella stabilità del prodotto. Nello stato gommoso, che si verifica a temperature superiori alla Tg, le molecole sono più mobili, rendendo il prodotto più soffice ma anche più instabile e suscettibile a fenomeni come l'agglomerazione (caking) e il collasso strutturale. [2, 7] Nello stato vetroso, invece, la mobilità è estremamente ridotta, garantendo una struttura rigida e stabile.",
#   'question_id': 12},
#  {'id': 39,
#   'prompt': "In che modo l'acqua influenza la transizione vetrosa di un alimento?",
#   'input': "In che modo l'acqua influenza la transizione vetrosa di un alimento?",
#   'context': "L'acqua agisce come un 'plasticizzante', ovvero la sua presenza abbassa la temperatura di transizione vetrosa (Tg) di un alimento. [6] Durante la disidratazione, la rimozione dell'acqua causa un innalzamento della Tg. È quindi fondamentale ridurre l'umidità residua a un livello tale che, alla temperatura di conservazione, il prodotto si trovi stabilmente nello stato vetroso, garantendone la qualità nel tempo.",
#   'target': "L'acqua agisce come un 'plasticizzante', ovvero la sua presenza abbassa la temperatura di transizione vetrosa (Tg) di un alimento. [6] Durante la disidratazione, la rimozione dell'acqua causa un innalzamento della Tg. È quindi fondamentale ridurre l'umidità residua a un livello tale che, alla temperatura di conservazione, il prodotto si trovi stabilmente nello stato vetroso, garantendone la qualità nel tempo.",
#   'question_id': 13},
#  {'id': 40,
#   'prompt': "In che modo l'acqua influenza la transizione vetrosa di un alimento?",
#   'input': "In che modo l'acqua influenza la transizione vetrosa di un alimento?",
#   'context': "L'acqua agisce come un 'plasticizzante', ovvero la sua presenza abbassa la temperatura di transizione vetrosa (Tg) di un alimento. [6] Durante la disidratazione, la rimozione dell'acqua causa un innalzamento della Tg. È quindi fondamentale ridurre l'umidità residua a un livello tale che, alla temperatura di conservazione, il prodotto si trovi stabilmente nello stato vetroso, garantendone la qualità nel tempo.",
#   'target': "L'acqua agisce come un 'plasticizzante', ovvero la sua presenza abbassa la temperatura di transizione vetrosa (Tg) di un alimento. [6] Durante la disidratazione, la rimozione dell'acqua causa un innalzamento della Tg. È quindi fondamentale ridurre l'umidità residua a un livello tale che, alla temperatura di conservazione, il prodotto si trovi stabilmente nello stato vetroso, garantendone la qualità nel tempo.",
#   'question_id': 13},
#  {'id': 41,
#   'prompt': "In che modo l'acqua influenza la transizione vetrosa di un alimento?",
#   'input': "In che modo l'acqua influenza la transizione vetrosa di un alimento?",
#   'context': "L'acqua agisce come un 'plasticizzante', ovvero la sua presenza abbassa la temperatura di transizione vetrosa (Tg) di un alimento. [6] Durante la disidratazione, la rimozione dell'acqua causa un innalzamento della Tg. È quindi fondamentale ridurre l'umidità residua a un livello tale che, alla temperatura di conservazione, il prodotto si trovi stabilmente nello stato vetroso, garantendone la qualità nel tempo.",
#   'target': "L'acqua agisce come un 'plasticizzante', ovvero la sua presenza abbassa la temperatura di transizione vetrosa (Tg) di un alimento. [6] Durante la disidratazione, la rimozione dell'acqua causa un innalzamento della Tg. È quindi fondamentale ridurre l'umidità residua a un livello tale che, alla temperatura di conservazione, il prodotto si trovi stabilmente nello stato vetroso, garantendone la qualità nel tempo.",
#   'question_id': 13},
#  {'id': 42,
#   'prompt': "Cosa significa che lo stato vetroso di un alimento è 'reversibile'?",
#   'input': "Cosa significa che lo stato vetroso di un alimento è 'reversibile'?",
#   'context': "Lo stato vetroso è definito 'reversibile' perché se un prodotto disidratato e stabile riassorbe umidità dall'ambiente, la sua temperatura di transizione vetrosa (Tg) si abbassa. Se la Tg scende al di sotto della temperatura di conservazione, il prodotto può passare dallo stato vetroso a quello gommoso, perdendo la sua croccantezza, la sua stabilità e diventando suscettibile a processi degradativi.",
#   'target': "Lo stato vetroso è definito 'reversibile' perché se un prodotto disidratato e stabile riassorbe umidità dall'ambiente, la sua temperatura di transizione vetrosa (Tg) si abbassa. Se la Tg scende al di sotto della temperatura di conservazione, il prodotto può passare dallo stato vetroso a quello gommoso, perdendo la sua croccantezza, la sua stabilità e diventando suscettibile a processi degradativi.",
#   'question_id': 14},
#  {'id': 43,
#   'prompt': "Cosa significa che lo stato vetroso di un alimento è 'reversibile'?",
#   'input': "Cosa significa che lo stato vetroso di un alimento è 'reversibile'?",
#   'context': "Lo stato vetroso è definito 'reversibile' perché se un prodotto disidratato e stabile riassorbe umidità dall'ambiente, la sua temperatura di transizione vetrosa (Tg) si abbassa. Se la Tg scende al di sotto della temperatura di conservazione, il prodotto può passare dallo stato vetroso a quello gommoso, perdendo la sua croccantezza, la sua stabilità e diventando suscettibile a processi degradativi.",
#   'target': "Lo stato vetroso è definito 'reversibile' perché se un prodotto disidratato e stabile riassorbe umidità dall'ambiente, la sua temperatura di transizione vetrosa (Tg) si abbassa. Se la Tg scende al di sotto della temperatura di conservazione, il prodotto può passare dallo stato vetroso a quello gommoso, perdendo la sua croccantezza, la sua stabilità e diventando suscettibile a processi degradativi.",
#   'question_id': 14},
#  {'id': 44,
#   'prompt': "Cosa significa che lo stato vetroso di un alimento è 'reversibile'?",
#   'input': "Cosa significa che lo stato vetroso di un alimento è 'reversibile'?",
#   'context': "Lo stato vetroso è definito 'reversibile' perché se un prodotto disidratato e stabile riassorbe umidità dall'ambiente, la sua temperatura di transizione vetrosa (Tg) si abbassa. Se la Tg scende al di sotto della temperatura di conservazione, il prodotto può passare dallo stato vetroso a quello gommoso, perdendo la sua croccantezza, la sua stabilità e diventando suscettibile a processi degradativi.",
#   'target': "Lo stato vetroso è definito 'reversibile' perché se un prodotto disidratato e stabile riassorbe umidità dall'ambiente, la sua temperatura di transizione vetrosa (Tg) si abbassa. Se la Tg scende al di sotto della temperatura di conservazione, il prodotto può passare dallo stato vetroso a quello gommoso, perdendo la sua croccantezza, la sua stabilità e diventando suscettibile a processi degradativi.",
#   'question_id': 14},
#  {'id': 45,
#   'prompt': 'Come vengono modificate le caratteristiche sensoriali come sapore e aroma durante la disidratazione?',
#   'input': 'Come vengono modificate le caratteristiche sensoriali come sapore e aroma durante la disidratazione?',
#   'context': "Le caratteristiche sensoriali di un alimento vengono modificate dalla disidratazione principalmente in due modi: da un lato, si ha una perdita di composti volatili originali a causa del calore, che riduce l'intensità dell'aroma fresco; dall'altro, si possono formare nuovi composti aromatici, spesso descritti come 'cotti' o 'tostati', a seguito di reazioni chimiche indotte dal calore.",
#   'target': "Le caratteristiche sensoriali di un alimento vengono modificate dalla disidratazione principalmente in due modi: da un lato, si ha una perdita di composti volatili originali a causa del calore, che riduce l'intensità dell'aroma fresco; dall'altro, si possono formare nuovi composti aromatici, spesso descritti come 'cotti' o 'tostati', a seguito di reazioni chimiche indotte dal calore.",
#   'question_id': 15},
#  {'id': 46,
#   'prompt': 'Come vengono modificate le caratteristiche sensoriali come sapore e aroma durante la disidratazione?',
#   'input': 'Come vengono modificate le caratteristiche sensoriali come sapore e aroma durante la disidratazione?',
#   'context': "Le caratteristiche sensoriali di un alimento vengono modificate dalla disidratazione principalmente in due modi: da un lato, si ha una perdita di composti volatili originali a causa del calore, che riduce l'intensità dell'aroma fresco; dall'altro, si possono formare nuovi composti aromatici, spesso descritti come 'cotti' o 'tostati', a seguito di reazioni chimiche indotte dal calore.",
#   'target': "Le caratteristiche sensoriali di un alimento vengono modificate dalla disidratazione principalmente in due modi: da un lato, si ha una perdita di composti volatili originali a causa del calore, che riduce l'intensità dell'aroma fresco; dall'altro, si possono formare nuovi composti aromatici, spesso descritti come 'cotti' o 'tostati', a seguito di reazioni chimiche indotte dal calore.",
#   'question_id': 15},
#  {'id': 47,
#   'prompt': 'Come vengono modificate le caratteristiche sensoriali come sapore e aroma durante la disidratazione?',
#   'input': 'Come vengono modificate le caratteristiche sensoriali come sapore e aroma durante la disidratazione?',
#   'context': "Le caratteristiche sensoriali di un alimento vengono modificate dalla disidratazione principalmente in due modi: da un lato, si ha una perdita di composti volatili originali a causa del calore, che riduce l'intensità dell'aroma fresco; dall'altro, si possono formare nuovi composti aromatici, spesso descritti come 'cotti' o 'tostati', a seguito di reazioni chimiche indotte dal calore.",
#   'target': "Le caratteristiche sensoriali di un alimento vengono modificate dalla disidratazione principalmente in due modi: da un lato, si ha una perdita di composti volatili originali a causa del calore, che riduce l'intensità dell'aroma fresco; dall'altro, si possono formare nuovi composti aromatici, spesso descritti come 'cotti' o 'tostati', a seguito di reazioni chimiche indotte dal calore.",
#   'question_id': 15},
#  {'id': 48,
#   'prompt': "Per quale motivo l'aroma di un prodotto disidratato è spesso meno intenso rispetto a quello del prodotto fresco?",
#   'input': "Per quale motivo l'aroma di un prodotto disidratato è spesso meno intenso rispetto a quello del prodotto fresco?",
# ...
#   'question_id': 115},
#  {'id': 348,
#   'prompt': "Che cos'è l'asse a* nello spazio colore CIELab e cosa misura esattamente?",
#   'input': "Che cos'è l'asse a* nello spazio colore CIELab e cosa misura esattamente?",
#   'context': "L'asse a* nello spazio colore CIELab rappresenta la componente cromatica che va dal verde al rosso. Un valore negativo di a* (-a*) indica la presenza di colore verde, mentre un valore positivo (+a*) indica la presenza di colore rosso. Un valore di a* vicino a zero corrisponde a un colore neutro (grigio) su questo asse.",
#   'target': "L'asse a* nello spazio colore CIELab rappresenta la componente cromatica che va dal verde al rosso. Un valore negativo di a* (-a*) indica la presenza di colore verde, mentre un valore positivo (+a*) indica la presenza di colore rosso. Un valore di a* vicino a zero corrisponde a un colore neutro (grigio) su questo asse.",
#   'question_id': 116},
#  {'id': 349,
#   'prompt': "Che cos'è l'asse a* nello spazio colore CIELab e cosa misura esattamente?",
#   'input': "Che cos'è l'asse a* nello spazio colore CIELab e cosa misura esattamente?",
#   'context': "L'asse a* nello spazio colore CIELab rappresenta la componente cromatica che va dal verde al rosso. Un valore negativo di a* (-a*) indica la presenza di colore verde, mentre un valore positivo (+a*) indica la presenza di colore rosso. Un valore di a* vicino a zero corrisponde a un colore neutro (grigio) su questo asse.",
#   'target': "L'asse a* nello spazio colore CIELab rappresenta la componente cromatica che va dal verde al rosso. Un valore negativo di a* (-a*) indica la presenza di colore verde, mentre un valore positivo (+a*) indica la presenza di colore rosso. Un valore di a* vicino a zero corrisponde a un colore neutro (grigio) su questo asse.",
#   'question_id': 116},
#  {'id': 350,
#   'prompt': "Che cos'è l'asse a* nello spazio colore CIELab e cosa misura esattamente?",
#   'input': "Che cos'è l'asse a* nello spazio colore CIELab e cosa misura esattamente?",
#   'context': "L'asse a* nello spazio colore CIELab rappresenta la componente cromatica che va dal verde al rosso. Un valore negativo di a* (-a*) indica la presenza di colore verde, mentre un valore positivo (+a*) indica la presenza di colore rosso. Un valore di a* vicino a zero corrisponde a un colore neutro (grigio) su questo asse.",
#   'target': "L'asse a* nello spazio colore CIELab rappresenta la componente cromatica che va dal verde al rosso. Un valore negativo di a* (-a*) indica la presenza di colore verde, mentre un valore positivo (+a*) indica la presenza di colore rosso. Un valore di a* vicino a zero corrisponde a un colore neutro (grigio) su questo asse.",
#   'question_id': 116},
#  {'id': 351,
#   'prompt': 'Come si interpreta una variazione del valore a* durante la disidratazione di un prodotto verde, come il prezzemolo o i piselli?',
#   'input': 'Come si interpreta una variazione del valore a* durante la disidratazione di un prodotto verde, come il prezzemolo o i piselli?',
#   'context': "Una variazione del valore a* in un prodotto verde si interpreta come un indicatore del degrado della clorofilla. Durante l'essiccazione, il valore a* (inizialmente negativo) tende ad aumentare, avvicinandosi allo zero o diventando positivo. Questo spostamento indica la conversione della clorofilla (verde brillante) in feofitina (verde-brunastro), segnalando un danno termico.",
#   'target': "Una variazione del valore a* in un prodotto verde si interpreta come un indicatore del degrado della clorofilla. Durante l'essiccazione, il valore a* (inizialmente negativo) tende ad aumentare, avvicinandosi allo zero o diventando positivo. Questo spostamento indica la conversione della clorofilla (verde brillante) in feofitina (verde-brunastro), segnalando un danno termico.",
#   'question_id': 117},
#  {'id': 352,
#   'prompt': 'Come si interpreta una variazione del valore a* durante la disidratazione di un prodotto verde, come il prezzemolo o i piselli?',
#   'input': 'Come si interpreta una variazione del valore a* durante la disidratazione di un prodotto verde, come il prezzemolo o i piselli?',
#   'context': "Una variazione del valore a* in un prodotto verde si interpreta come un indicatore del degrado della clorofilla. Durante l'essiccazione, il valore a* (inizialmente negativo) tende ad aumentare, avvicinandosi allo zero o diventando positivo. Questo spostamento indica la conversione della clorofilla (verde brillante) in feofitina (verde-brunastro), segnalando un danno termico.",
#   'target': "Una variazione del valore a* in un prodotto verde si interpreta come un indicatore del degrado della clorofilla. Durante l'essiccazione, il valore a* (inizialmente negativo) tende ad aumentare, avvicinandosi allo zero o diventando positivo. Questo spostamento indica la conversione della clorofilla (verde brillante) in feofitina (verde-brunastro), segnalando un danno termico.",
#   'question_id': 117},
#  {'id': 353,
#   'prompt': 'Come si interpreta una variazione del valore a* durante la disidratazione di un prodotto verde, come il prezzemolo o i piselli?',
#   'input': 'Come si interpreta una variazione del valore a* durante la disidratazione di un prodotto verde, come il prezzemolo o i piselli?',
#   'context': "Una variazione del valore a* in un prodotto verde si interpreta come un indicatore del degrado della clorofilla. Durante l'essiccazione, il valore a* (inizialmente negativo) tende ad aumentare, avvicinandosi allo zero o diventando positivo. Questo spostamento indica la conversione della clorofilla (verde brillante) in feofitina (verde-brunastro), segnalando un danno termico.",
#   'target': "Una variazione del valore a* in un prodotto verde si interpreta come un indicatore del degrado della clorofilla. Durante l'essiccazione, il valore a* (inizialmente negativo) tende ad aumentare, avvicinandosi allo zero o diventando positivo. Questo spostamento indica la conversione della clorofilla (verde brillante) in feofitina (verde-brunastro), segnalando un danno termico.",
#   'question_id': 117},
#  {'id': 354,
#   'prompt': "Cosa indica una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso come la fragola o il pomodoro?",
#   'input': "Cosa indica una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso come la fragola o il pomodoro?",
#   'context': "Una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso indica la degradazione dei pigmenti rossi, come le antocianine (nelle fragole) o il licopene (nei pomodori). Questo fenomeno, causato da calore e ossidazione, si traduce in una perdita di intensità e vivacità del colore rosso, rendendo il prodotto più sbiadito.",
#   'target': "Una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso indica la degradazione dei pigmenti rossi, come le antocianine (nelle fragole) o il licopene (nei pomodori). Questo fenomeno, causato da calore e ossidazione, si traduce in una perdita di intensità e vivacità del colore rosso, rendendo il prodotto più sbiadito.",
#   'question_id': 118},
#  {'id': 355,
#   'prompt': "Cosa indica una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso come la fragola o il pomodoro?",
#   'input': "Cosa indica una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso come la fragola o il pomodoro?",
#   'context': "Una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso indica la degradazione dei pigmenti rossi, come le antocianine (nelle fragole) o il licopene (nei pomodori). Questo fenomeno, causato da calore e ossidazione, si traduce in una perdita di intensità e vivacità del colore rosso, rendendo il prodotto più sbiadito.",
#   'target': "Una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso indica la degradazione dei pigmenti rossi, come le antocianine (nelle fragole) o il licopene (nei pomodori). Questo fenomeno, causato da calore e ossidazione, si traduce in una perdita di intensità e vivacità del colore rosso, rendendo il prodotto più sbiadito.",
#   'question_id': 118},
#  {'id': 356,
#   'prompt': "Cosa indica una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso come la fragola o il pomodoro?",
#   'input': "Cosa indica una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso come la fragola o il pomodoro?",
#   'context': "Una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso indica la degradazione dei pigmenti rossi, come le antocianine (nelle fragole) o il licopene (nei pomodori). Questo fenomeno, causato da calore e ossidazione, si traduce in una perdita di intensità e vivacità del colore rosso, rendendo il prodotto più sbiadito.",
#   'target': "Una diminuzione del valore positivo di a* durante l'essiccazione di un frutto rosso indica la degradazione dei pigmenti rossi, come le antocianine (nelle fragole) o il licopene (nei pomodori). Questo fenomeno, causato da calore e ossidazione, si traduce in una perdita di intensità e vivacità del colore rosso, rendendo il prodotto più sbiadito.",
#   'question_id': 118},
#  {'id': 357,
#   'prompt': 'In che modo le reazioni di imbrunimento, come la reazione di Maillard, influenzano il parametro a*?',
#   'input': 'In che modo le reazioni di imbrunimento, come la reazione di Maillard, influenzano il parametro a*?',
#   'context': "Le reazioni di imbrunimento influenzano il parametro a* facendolo aumentare verso valori più positivi. La formazione di composti bruni (melanoidine) durante la reazione di Maillard aggiunge una componente rossastra al colore complessivo del prodotto. Pertanto, un monitoraggio dell'incremento di a* è un metodo efficace per quantificare e controllare l'avanzamento dell'imbrunimento.",
#   'target': "Le reazioni di imbrunimento influenzano il parametro a* facendolo aumentare verso valori più positivi. La formazione di composti bruni (melanoidine) durante la reazione di Maillard aggiunge una componente rossastra al colore complessivo del prodotto. Pertanto, un monitoraggio dell'incremento di a* è un metodo efficace per quantificare e controllare l'avanzamento dell'imbrunimento.",
#   'question_id': 119},
#  {'id': 358,
#   'prompt': 'In che modo le reazioni di imbrunimento, come la reazione di Maillard, influenzano il parametro a*?',
#   'input': 'In che modo le reazioni di imbrunimento, come la reazione di Maillard, influenzano il parametro a*?',
#   'context': "Le reazioni di imbrunimento influenzano il parametro a* facendolo aumentare verso valori più positivi. La formazione di composti bruni (melanoidine) durante la reazione di Maillard aggiunge una componente rossastra al colore complessivo del prodotto. Pertanto, un monitoraggio dell'incremento di a* è un metodo efficace per quantificare e controllare l'avanzamento dell'imbrunimento.",
#   'target': "Le reazioni di imbrunimento influenzano il parametro a* facendolo aumentare verso valori più positivi. La formazione di composti bruni (melanoidine) durante la reazione di Maillard aggiunge una componente rossastra al colore complessivo del prodotto. Pertanto, un monitoraggio dell'incremento di a* è un metodo efficace per quantificare e controllare l'avanzamento dell'imbrunimento.",
#   'question_id': 119},
#  {'id': 359,
#   'prompt': 'In che modo le reazioni di imbrunimento, come la reazione di Maillard, influenzano il parametro a*?',
#   'input': 'In che modo le reazioni di imbrunimento, come la reazione di Maillard, influenzano il parametro a*?',
#   'context': "Le reazioni di imbrunimento influenzano il parametro a* facendolo aumentare verso valori più positivi. La formazione di composti bruni (melanoidine) durante la reazione di Maillard aggiunge una componente rossastra al colore complessivo del prodotto. Pertanto, un monitoraggio dell'incremento di a* è un metodo efficace per quantificare e controllare l'avanzamento dell'imbrunimento.",
#   'target': "Le reazioni di imbrunimento influenzano il parametro a* facendolo aumentare verso valori più positivi. La formazione di composti bruni (melanoidine) durante la reazione di Maillard aggiunge una componente rossastra al colore complessivo del prodotto. Pertanto, un monitoraggio dell'incremento di a* è un metodo efficace per quantificare e controllare l'avanzamento dell'imbrunimento.",
#   'question_id': 119},
#  {'id': 360,
#   'prompt': 'Come può essere utilizzato il monitoraggio del parametro a* per controllare attivamente il processo di disidratazione?',
#   'input': 'Come può essere utilizzato il monitoraggio del parametro a* per controllare attivamente il processo di disidratazione?',
#   'context': "Il monitoraggio in tempo reale del parametro a* può essere utilizzato come feedback per un controllo attivo del processo: se la velocità di variazione di a* (es. la perdita di verde) supera una soglia predefinita, il sistema può ridurre automaticamente la temperatura dell'aria per applicare un trattamento termico più delicato, preservando così il colore e la qualità del prodotto finale.",
#   'target': "Il monitoraggio in tempo reale del parametro a* può essere utilizzato come feedback per un controllo attivo del processo: se la velocità di variazione di a* (es. la perdita di verde) supera una soglia predefinita, il sistema può ridurre automaticamente la temperatura dell'aria per applicare un trattamento termico più delicato, preservando così il colore e la qualità del prodotto finale.",
#   'question_id': 120},
#  {'id': 361,
#   'prompt': 'Come può essere utilizzato il monitoraggio del parametro a* per controllare attivamente il processo di disidratazione?',
#   'input': 'Come può essere utilizzato il monitoraggio del parametro a* per controllare attivamente il processo di disidratazione?',
#   'context': "Il monitoraggio in tempo reale del parametro a* può essere utilizzato come feedback per un controllo attivo del processo: se la velocità di variazione di a* (es. la perdita di verde) supera una soglia predefinita, il sistema può ridurre automaticamente la temperatura dell'aria per applicare un trattamento termico più delicato, preservando così il colore e la qualità del prodotto finale.",
#   'target': "Il monitoraggio in tempo reale del parametro a* può essere utilizzato come feedback per un controllo attivo del processo: se la velocità di variazione di a* (es. la perdita di verde) supera una soglia predefinita, il sistema può ridurre automaticamente la temperatura dell'aria per applicare un trattamento termico più delicato, preservando così il colore e la qualità del prodotto finale.",
#   'question_id': 120},
#  {'id': 362,
#   'prompt': 'Come può essere utilizzato il monitoraggio del parametro a* per controllare attivamente il processo di disidratazione?',
#   'input': 'Come può essere utilizzato il monitoraggio del parametro a* per controllare attivamente il processo di disidratazione?',
#   'context': "Il monitoraggio in tempo reale del parametro a* può essere utilizzato come feedback per un controllo attivo del processo: se la velocità di variazione di a* (es. la perdita di verde) supera una soglia predefinita, il sistema può ridurre automaticamente la temperatura dell'aria per applicare un trattamento termico più delicato, preservando così il colore e la qualità del prodotto finale.",
#   'target': "Il monitoraggio in tempo reale del parametro a* può essere utilizzato come feedback per un controllo attivo del processo: se la velocità di variazione di a* (es. la perdita di verde) supera una soglia predefinita, il sistema può ridurre automaticamente la temperatura dell'aria per applicare un trattamento termico più delicato, preservando così il colore e la qualità del prodotto finale.",
#   'question_id': 120}]

# %%
dataset = load_eval_dataset()

# %%
# |export
hallucination_scorer = HallucinationFreeScorer(
    model_id="vertex_ai/gemini-2.5-pro",
)

# %%
# |export
class CatEmbeddingSimilarityScorer(EmbeddingSimilarityScorer):
    @weave.op
    async def score(self, *, output: str, target: str, **kwargs: Any) -> Any:
        # Ensure the threshold is within the valid range for cosine similarity.
        assert -1 <= self.threshold <= 1, "`threshold` should be between -1 and 1"

        model_embedding, target_embedding = await self._compute_embeddings(
            output["text_clean"], target
        )
        return self._cosine_similarity(model_embedding, target_embedding)


similarity_scorer = CatEmbeddingSimilarityScorer(
    model_id="vertex_ai/gemini-embedding-001",
    threshold=0.8,
)

# %%
#| export
def read_sentences():
    path = here("eval/declarative_memory.csv")
    df = pd.read_csv(path)
    return df['risposta'].tolist()

# %%
#| export
def prepare_declarative_memory(client: SuperCatClient):
    client.wipe_declarative_memory()
    sentences = read_sentences()
    client.put_sentences(sentences)
    print(f"Added {len(sentences)} sentences to declarative memory")

# %%
#|export
async def eval_configs(dataset, n_rep=1, model_confs=conf_variants):
    client = SuperCatClient()
    time = datetime.now().strftime("%m-%d %H:%M")
    eval_name = f"{time} Eval"
    prepare_declarative_memory(client)
    evaluation = weave.Evaluation(
        dataset=list(repeat_dataset(dataset, n_rep)),
        scorers=[hallucination_scorer, similarity_scorer],
        name=eval_name,
    )
    for name, conf in tqdm(model_confs.items(), total=len(model_confs)):
        print(f"Evaluating {name} with memory")
        model = CatModel(name, conf)
        await evaluation.evaluate(model, __weave={"display_name": f"{eval_name} - {name} memory"})
    client.wipe_declarative_memory()
    for name, conf in tqdm(model_confs.items(), total=len(model_confs)):
        print(f"Evaluating {name} without memory")
        model = CatModel(name, conf, has_declarative_memory=False)
        await evaluation.evaluate(model, __weave={"display_name": f"{eval_name} - {name} NO memory"})

# %%
weave.init("dev-test")

# %%
await eval_configs(dataset[:2])
